# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'  
}

# %%
def info(p,company,class1):
    res = requests.get('https://goodinfo.tw/StockInfo/StockFinDetail.asp?RPT_CAT={}&STOCK_ID={}'.format(p,company),headers=headers)
    res.encoding = 'utf-8'
    soup = BeautifulSoup(res.text,"lxml")
    t= soup.select('.{}'.format(class1))
    t1 = pd.read_html(str(t[0]))
    t1 = pd.DataFrame(t1[0])
    return t1

# %%
#year也許要改
def info2(p,company,class1):
    res = requests.get('https://goodinfo.tw/StockInfo/StockFinGrade.asp?STOCK_ID={}&RPT_CAT={}&QRY_TIME=20183'.format(company,p),headers=headers)
    res.encoding = 'utf-8'
    soup = BeautifulSoup(res.text,"lxml")
    t= soup.select('.{}'.format(class1))
    t1 = pd.read_html(str(t[0]))
    t1 = pd.DataFrame(t1[0])
    return t1

# %%
#資產負債表
#BS_M_QUAR 合併季表
#BS_M_YEAR 合併年表
#BS_QUAR 非合併季表 
#BS_YEAR 非合併年表
#BS_EZ_M_QUAR 合併簡式季表
#BS_EZ_M_YEAR 合併簡式年表
#BS_EZ_QUAR 非合併簡式季表
#BS_EZ_YEAR 非合併簡式年表

BS_M_QUAR = info('BS_M_QUAR','2891','solid_1_padding_4_4_tbl')
BS_M_YEAR = info('BS_M_YEAR','2891','solid_1_padding_4_4_tbl')
BS_QUAR = info('BS_QUAR','2891','solid_1_padding_4_4_tbl')
BS_YEAR = info('BS_YEAR','2891','solid_1_padding_4_4_tbl')
BS_EZ_M_QUAR = info('BS_EZ_M_QUAR','2891','solid_1_padding_4_4_tbl')
BS_EZ_M_YEAR = info('BS_EZ_M_YEAR','2891','solid_1_padding_4_4_tbl')
BS_EZ_QUAR = info('BS_EZ_QUAR','2891','solid_1_padding_4_4_tbl')
BS_EZ_YEAR = info('BS_EZ_YEAR','2891','solid_1_padding_4_4_tbl')

#損益表
#IS_M_QUAR 合併單季季表
#IS_M_QUAR_ACC 合併年表
#IS_QUAR 非合併單季季表
#IS_QUAR_ACC 非合併累計季表
#IS_YEAR 非合併年表
#IS_EZ_M_QUAR 合併簡式單季季表
#IS_EZ_M_QUAR_ACC 合併簡式累計季表
#IS_EZ_M_YEAR 合併簡式年表
#IS_EZ_QUAR 非合併簡式單季季表
#IS_EZ_QUAR_ACC 非合併簡式累計季表
#IS_EZ_YEAR 非合併簡式年表
#flag=['IS_M_QUAR','IS_M_QUAR_ACC','IS_QUAR','IS_QUAR_ACC','IS_YEAR','IS_EZ_M_QUAR','IS_EZ_M_QUAR_ACC','IS_EZ_M_YEAR','IS_EZ_QUAR','IS_EZ_QUAR_ACC','IS_EZ_YEAR']

Profit_loss_M = info('IS_M_QUAR','2891','solid_1_padding_4_4_tbl')
Profit_loss_M_Acc = info('IS_M_QUAR_ACC','2891','solid_1_padding_4_4_tbl')
Profit_loss_Quar = info('IS_QUAR','2891','solid_1_padding_4_4_tbl')
Profit_loss_Quar_Acc = info('IS_QUAR_ACC','2891','solid_1_padding_4_4_tbl')
Profit_loss_Is_year = info('IS_YEAR','2891','solid_1_padding_4_4_tbl')
Profit_loss_is_ez_m_quar = info('IS_EZ_M_QUAR','2891','solid_1_padding_4_4_tbl')
Profit_loss_is_ez_m_year = info('IS_EZ_M_YEAR','2891','solid_1_padding_4_4_tbl')
Profit_loss_is_ez_quar = info('IS_EZ_QUAR','2891','solid_1_padding_4_4_tbl')
Profit_loss_is_ez_quar_acc = info('IS_EZ_QUAR_ACC','2891','solid_1_padding_4_4_tbl')
Profit_loss_is_ez_year = info('IS_EZ_YEAR','2891','solid_1_padding_4_4_tbl')

#流量表
#CF_M_QUAR 合併單季季表
#CF_M_QUAR_ACC 合併累計季表
#CF_M_YEAR  合併年表
#CF_QUAR 非合併單季季表
#CF_QUAR_ACC 非合併累計季表
#CF_YEAR 非合併年表
CF_M_QUAR = info('CF_M_QUAR','2891','solid_1_padding_4_4_tbl')
CF_M_QUAR_ACC = info('CF_M_QUAR_ACC','2891','solid_1_padding_4_4_tbl')
CF_M_YEAR = info('CF_M_YEAR','2891','solid_1_padding_4_4_tbl')
CF_QUAR = info('CF_QUAR','2891','solid_1_padding_4_4_tbl')
CF_QUAR_ACC = info('CF_QUAR_ACC','2891','solid_1_padding_4_4_tbl')
CF_YEAR = info('CF_YEAR','2891','solid_1_padding_4_4_tbl')

#財務比率表
XX_M_QUAR = info('XX_M_QUAR','2891','solid_1_padding_4_4_tbl')
XX_M_QUAR_ACC = info('XX_M_QUAR_ACC','2891','solid_1_padding_4_4_tbl')
XX_QUAR = info('XX_QUAR','2891','solid_1_padding_4_4_tbl')
XX_QUAR_ACC = info('XX_QUAR_ACC','2891','solid_1_padding_4_4_tbl')
XX_YEAR = info('XX_YEAR','2891','solid_1_padding_4_4_tbl')

#財務評分表
M_QUAR = info2('M_QUAR','2891','solid_1_padding_4_3_tbl')
M_QUAR_ACC = info2('M_QUAR_ACC','2891','solid_1_padding_4_3_tbl')
M_YEAR = info2('M_YEAR','2891','solid_1_padding_4_3_tbl')
QUAR = info2('QUAR','2891','solid_1_padding_4_3_tbl')
QUAR_ACC = info2('QUAR_ACC','2891','solid_1_padding_4_3_tbl')
YEAR = info2('YEAR','2891','solid_1_padding_4_3_tbl')

# %%
YEAR = info2('YEAR','2891','solid_1_padding_4_3_tbl')
YEAR
# Out:
#             0          1     2    3                              4   \
# 0           類別       評分項目     ％   總分                             得分
# 1         資產佔比     現金 (%)   2.9    3                              0
# 2          NaN        ~ 5  ：0 分  NaN                            NaN
# 3          NaN     5 ~ 10  ：1 分  NaN                            NaN
# 4          NaN    10 ~ 15  ：2 分  NaN                            NaN
# 5          NaN       15 ~  ：3 分  NaN                            NaN
# 6         資產佔比   應收帳款 (%)   2.9    3                              3
# 7          NaN       ~ 10  ：3 分  NaN                            NaN
# 8          NaN    10 ~ 20  ：2 分  NaN                            NaN
# 9          NaN    20 ~ 30  ：1 分  NaN                            NaN
# 10         NaN       30 ~  ：0 分  NaN                            NaN
# 11        資產佔比  基金及投資 (%)  32.6    3                              1
# 12         NaN       ~ 10  ：3 分  NaN                            NaN
# ...

# %%
BS_QUAR
# Out:
#                                                    0
# 0  2891 中信金 非合併資產負債季表　(單位：億元) 合併季表合併年表非合併季表非合併年表合...

# %%
res = requests.get('https://goodinfo.tw/StockInfo/StockFinDetail.asp?RPT_CAT={}&STOCK_ID={}'.format('BS_QUAR','2891'),headers=headers)
res.encoding = 'utf-8'
soup = BeautifulSoup(res.text,"lxml")
t= soup.select('.{}'.format('solid_1_padding_4_4_tbl'))
t1 = pd.read_html(str(t[0]))
t1 = pd.DataFrame(t1[0])

# %% [markdown]
# ## 現金流量表

# %%
t1
# Out:
#                     0            1       2            3       4            5   \
# 0                   資產       2018Q3  2018Q2       2018Q1  2017Q4       2017Q3
# 1                   金額  &nbsp％&nbsp      金額  &nbsp％&nbsp      金額  &nbsp％&nbsp
# 2              現金及約當現金         1377    2.42         1130    2.04         1356
# 3          存放央行及拆借金融同業         2744    4.82         2667    4.81         2509
# 4   公平價值衡量列入損益之金融資產–流動         8325    14.6         7564    13.6         7336
# 5          備供出售金融資產–流動            0       0            0       0            0
# 6        避險之衍生性金融資產–流動          3.2    0.01         1.49       0         1.77
# 7     以攤銷後成本衡量之金融資產–流動        15996    28.1        16156    29.1        15851
# 8           附賣回票券及債券投資        389.1    0.68        108.5     0.2        166.3
# 9               短期投資合計        24713    43.4        23830      43        23355
# 10          再保險準備資產–流動        24.34    0.04        26.94    0.05        28.06
# ...

# %%
solid_1_padding_4_4_tbl
